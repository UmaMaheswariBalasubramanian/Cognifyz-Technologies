# %% [markdown]
# # Task 1

# %% [markdown]
# # Data Exploration and Preprocessing
#
# Explore the dataset and identify the number
# of rows and columns.
#
# Check for missing values in each column and
# handle them accordingly.
#
# Perform data type conversion if necessary.
# Analyze the distribution of the target variable
# ("Aggregate rating") and identify any class
# imbalances.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("Dataset.csv") #Explore the dataset

# %%
df1.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.shape #number of rows and columns
# Out:
# (9551, 21)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# #### missing values

# %%
df1.isnull().sum().any()
# Out:
# True

# %%
df1 = df1.fillna(method = "bfill")
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.isnull().sum().any()
# Out:
# False

# %% [markdown]
# No Missing values, The dataset has cleaned

# %%
df1.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
#Analyze the distribution of the target variable ("Aggregate rating") and identify any class imbalances.

target_variable = 'Aggregate rating'

# Analyze the distribution of the target variable
plt.figure(figsize=(8, 6))
sns.histplot(df1[target_variable], kde=True)
plt.xlabel("Target Variable")
plt.ylabel("Frequency")
plt.title("Distribution of Target Variable")
plt.show()

# %%
# Identify class imbalances for a classification problem
if df1[target_variable].dtype == 'object':
    class_counts = df1[target_variable].value_counts()
    print(class_counts)

    plt.figure(figsize=(8, 6))
    sns.countplot(data=df1, x=target_variable)
    plt.xlabel("Target Variable")
    plt.ylabel("Count")
    plt.title("Class Distribution")
    plt.xticks(rotation=45)  # Rotate x-axis labels if needed
    plt.show()
else:
    print("The target variable is not categorical, it might be a regression problem.")
# Out:
# The target variable is not categorical, it might be a regression problem.

# %% [markdown]
# # Task 2

# %% [markdown]
# # Descriptive Analysis
#
# Descriptive analysis, also known as descriptive statistics, is a branch of statistics and data analysis that focuses on summarizing and describing the main features of a dataset. Its primary purpose is to provide a clear and concise overview of the data, enabling you to understand its characteristics without making inferences or drawing conclusions about a larger population.
#
#
# ### Problem Statement
#
# Calculate basic statistical measures (mean,
# median, standard deviation, etc.) for numerical
# columns.
#
# Explore the distribution of categorical
# variables like "Country Code","City" and "Cuisines".
#
# Identify the top cuisines and cities with the
# highest number of restaurants.

# %%
# Calculate basic statistical measures for numerical columns
numeric_columns = df1.select_dtypes(include=[np.number])
statistics = numeric_columns.describe()

# %%
df1.mean()
# Out:
# C:\Users\MYPC~1\AppData\Local\Temp/ipykernel_12224/2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# Restaurant ID           9.051128e+06
# Country Code            1.836562e+01
# Longitude               6.412657e+01
# Latitude                2.585438e+01
# Average Cost for two    1.199211e+03
# Price range             1.804837e+00
# Aggregate rating        2.666370e+00
# Votes                   1.569097e+02
# dtype: float64

# %%
df1.median()
# Out:
# C:\Users\MYPC~1\AppData\Local\Temp/ipykernel_12224/2279417019.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.median()
# Restaurant ID           6.004089e+06
# Country Code            1.000000e+00
# Longitude               7.719196e+01
# Latitude                2.857047e+01
# Average Cost for two    4.000000e+02
# Price range             2.000000e+00
# Aggregate rating        3.200000e+00
# Votes                   3.100000e+01
# dtype: float64

# %%
df1.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# Explore the distribution of categorical variables
categorical_columns = df1.select_dtypes(include=[np.object])
for col in categorical_columns.columns:
    sns.countplot(data=df1, x=col)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)  # Rotate x-axis labels if needed
    plt.show()

# Identify the top cuisines
top_cuisines = df1['Cuisines'].value_counts().head(10)

# Identify the top cities with the highest number of restaurants
top_cities = df1['City'].value_counts().head(10)

print("Basic Statistical Measures for Numerical Columns:")
print(statistics)

print("\nTop 10 Cuisines:")
print(top_cuisines)

print("\nTop 10 Cities with the Highest Number of Restaurants:")
print(top_cities)
# Out:
# C:\Users\MYPC~1\AppData\Local\Temp/ipykernel_12224/2859641667.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical_columns = df1.select_dtypes(include=[np.object])
# Basic Statistical Measures for Numerical Columns:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# ...

# %% [markdown]
# # Task 3

# %% [markdown]
# # Geospatial Analysis
# Geospatial analysis involves working with location-based data, such as latitude and longitude, to gain insights into geographical patterns. To perform geospatial analysis on a dataset of restaurants

# %% [markdown]
# ### Problrem Statement:
#
# Visualize the locations of restaurants on a
# map using latitude and longitude
# information.

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
# Create a map centered at a specific location (e.g., city's coordinates or the mean of lat/lon)
restaurant_map = folium.Map(location=[df1['Latitude'].mean(), df1['Longitude'].mean()], zoom_start=12)

# Add markers for each restaurant
for index, row in df1.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Restaurant Name']
    ).add_to(restaurant_map)

# Save or display the map
restaurant_map.save('restaurant_locations_map.html')

# %% [markdown]
# Analyze the distribution of restaurants
# across different cities or countries.
# Determine if there is any correlation
# between the restaurant's location and its
# rating.

# %%
city_distribution = df1['City'].value_counts()
print("Distribution of Restaurants by City:\n", city_distribution)
# Out:
# Distribution of Restaurants by City:
#  New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %%
country_distribution = df1['Country Code'].value_counts()
print("Distribution of Restaurants by Country:\n", country_distribution)
# Out:
# Distribution of Restaurants by Country:
#  1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64

# %%
#To determine if there is any correlation between the restaurant's location (latitude and longitude) 
import seaborn as sns

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Latitude', y='Longitude', hue='Rating color', data=df1)
plt.title("Correlation Between Location and Rating")
plt.show()

# Calculate the correlation coefficient
correlation_coefficient = df1['Latitude'].corr(df1['Rating color'])
print("Correlation Coefficient between Latitude and Rating:", correlation_coefficient)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\MYPC~1\AppData\Local\Temp/ipykernel_12224/1550803037.py in <module>
#       9
#      10 # Calculate the correlation coefficient
# ---> 11 correlation_coefficient = df1['Latitude'].corr(df1['Rating color'])
#      12 print("Correlation Coefficient between Latitude and Rating:", correlation_coefficient)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2506
#    2507         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2508             return nanops.nancorr(
#    2509                 this.values, other.values, method=method, min_periods=min_periods
#    2510             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      91             try:
# ...
